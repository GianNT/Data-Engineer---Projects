# %%
def create_url(year=2016, month=1, date=1, time=1):
    year = f'{int(year):04}'
    month = f'{int(month):02}'
    date = f'{int(date):02}'
    time = f'{int(time):02}'
    url = f'https://dumps.wikimedia.org/other/pageviews/{year}/{year}-{month}/pageviews-{year}{month}{date}-{time}0000.gz'
    return url

# %%
year_pattern = 2016
month_pattern = 1
data_pattern = range(1, 32)
time_pattern = range(0,24)
pattern_urls = [create_url(year_pattern, month_pattern, date = j, time=i) for j in data_pattern for i in time_pattern]

# %%
parquet_need = []
for url in pattern_urls:
    parquet_filename = (url.strip().split("/")[-1].replace(".gz",".parquet"))
    parquet_need.append(parquet_filename)

print(len(parquet_need))
print(parquet_need)
# Out:
# 744
# ['pageviews-20160101-000000.parquet', 'pageviews-20160101-010000.parquet', 'pageviews-20160101-020000.parquet', 'pageviews-20160101-030000.parquet', 'pageviews-20160101-040000.parquet', 'pageviews-20160101-050000.parquet', 'pageviews-20160101-060000.parquet', 'pageviews-20160101-070000.parquet', 'pageviews-20160101-080000.parquet', 'pageviews-20160101-090000.parquet', 'pageviews-20160101-100000.parquet', 'pageviews-20160101-110000.parquet', 'pageviews-20160101-120000.parquet', 'pageviews-20160101-130000.parquet', 'pageviews-20160101-140000.parquet', 'pageviews-20160101-150000.parquet', 'pageviews-20160101-160000.parquet', 'pageviews-20160101-170000.parquet', 'pageviews-20160101-180000.parquet', 'pageviews-20160101-190000.parquet', 'pageviews-20160101-200000.parquet', 'pageviews-20160101-210000.parquet', 'pageviews-20160101-220000.parquet', 'pageviews-20160101-230000.parquet', 'pageviews-20160102-000000.parquet', 'pageviews-20160102-010000.parquet', 'pageviews-20160102-020000.parquet', 'pageviews-20160102-030000.parquet', 'pageviews-20160102-040000.parquet', 'pageviews-20160102-050000.parquet', 'pageviews-20160102-060000.parquet', 'pageviews-20160102-070000.parquet', 'pageviews-20160102-080000.parquet', 'pageviews-20160102-090000.parquet', 'pageviews-20160102-100000.parquet', 'pageviews-20160102-110000.parquet', 'pageviews-20160102-120000.parquet', 'pageviews-20160102-130000.parquet', 'pageviews-20160102-140000.parquet', 'pageviews-20160102-150000.parquet', 'pageviews-20160102-160000.parquet', 'pageviews-20160102-170000.parquet', 'pageviews-20160102-180000.parquet', 'pageviews-20160102-190000.parquet', 'pageviews-20160102-200000.parquet', 'pageviews-20160102-210000.parquet', 'pageviews-20160102-220000.parquet', 'pageviews-20160102-230000.parquet', 'pageviews-20160103-000000.parquet', 'pageviews-20160103-010000.parquet', 'pageviews-20160103-020000.parquet', 'pageviews-20160103-030000.parquet', 'pageviews-20160103-040000.parquet', 'pageviews-20160103-050000.parquet', 'pageviews-20160103-060000.parquet', 'pageviews-20160103-070000.parquet', 'pageviews-20160103-080000.parquet', 'pageviews-20160103-090000.parquet', 'pageviews-20160103-100000.parquet', 'pageviews-20160103-110000.parquet', 'pageviews-20160103-120000.parquet', 'pageviews-20160103-130000.parquet', 'pageviews-20160103-140000.parquet', 'pageviews-20160103-150000.parquet', 'pageviews-20160103-160000.parquet', 'pageviews-20160103-170000.parquet', 'pageviews-20160103-180000.parquet', 'pageviews-20160103-190000.parquet', 'pageviews-20160103-200000.parquet', 'pageviews-20160103-210000.parquet', 'pageviews-20160103-220000.parquet', 'pageviews-20160103-230000.parquet', 'pageviews-20160104-000000.parquet', 'pageviews-20160104-010000.parquet', 'pageviews-20160104-020000.parquet', 'pageviews-20160104-030000.parquet', 'pageviews-20160104-040000.parquet', 'pageviews-20160104-050000.parquet', 'pageviews-20160104-060000.parquet', 'pageviews-20160104-070000.parquet', 'pageviews-20160104-080000.parquet', 'pageviews-20160104-090000.parquet', 'pageviews-20160104-100000.parquet', 'pageviews-20160104-110000.parquet', 'pageviews-20160104-120000.parquet', 'pageviews-20160104-130000.parquet', 'pageviews-20160104-140000.parquet', 'pageviews-20160104-150000.parquet', 'pageviews-20160104-160000.parquet', 'pageviews-20160104-170000.parquet', 'pageviews-20160104-180000.parquet', 'pageviews-20160104-190000.parquet', 'pageviews-20160104-200000.parquet', 'pageviews-20160104-210000.parquet', 'pageviews-20160104-220000.parquet', 'pageviews-20160104-230000.parquet', 'pageviews-20160105-000000.parquet', 'pageviews-20160105-010000.parquet', 'pageviews-20160105-020000.parquet', 'pageviews-20160105-030000.parquet', 'pageviews-20160105-040000.parquet', 'pageviews-20160105-050000.parquet', 'pageviews-20160105-060000.parquet', 'pageviews-20160105-070000.parquet', 'pageviews-20160105-080000.parquet', 'pageviews-20160105-090000.parquet', 'pageviews-20160105-100000.parquet', 'pageviews-20160105-110000.parquet', 'pa ...

# %%
import os 
parquet_folder = "/Users/GianNT/Documents/Mr_G/Py_DE_Project/project_1_create_DW/download_test/parquet"
parquet_parttern = [file for file in os.listdir(parquet_folder) if file.endswith(".parquet")]

print(len(parquet_parttern))

print(sorted(parquet_parttern))
# Out:
# 744
# ['pageviews-20160101-000000.parquet', 'pageviews-20160101-010000.parquet', 'pageviews-20160101-020000.parquet', 'pageviews-20160101-030000.parquet', 'pageviews-20160101-040000.parquet', 'pageviews-20160101-050000.parquet', 'pageviews-20160101-060000.parquet', 'pageviews-20160101-070000.parquet', 'pageviews-20160101-080000.parquet', 'pageviews-20160101-090000.parquet', 'pageviews-20160101-100000.parquet', 'pageviews-20160101-110000.parquet', 'pageviews-20160101-120000.parquet', 'pageviews-20160101-130000.parquet', 'pageviews-20160101-140000.parquet', 'pageviews-20160101-150000.parquet', 'pageviews-20160101-160000.parquet', 'pageviews-20160101-170000.parquet', 'pageviews-20160101-180000.parquet', 'pageviews-20160101-190000.parquet', 'pageviews-20160101-200000.parquet', 'pageviews-20160101-210000.parquet', 'pageviews-20160101-220000.parquet', 'pageviews-20160101-230000.parquet', 'pageviews-20160102-000000.parquet', 'pageviews-20160102-010000.parquet', 'pageviews-20160102-020000.parquet', 'pageviews-20160102-030000.parquet', 'pageviews-20160102-040000.parquet', 'pageviews-20160102-050000.parquet', 'pageviews-20160102-060000.parquet', 'pageviews-20160102-070000.parquet', 'pageviews-20160102-080000.parquet', 'pageviews-20160102-090000.parquet', 'pageviews-20160102-100000.parquet', 'pageviews-20160102-110000.parquet', 'pageviews-20160102-120000.parquet', 'pageviews-20160102-130000.parquet', 'pageviews-20160102-140000.parquet', 'pageviews-20160102-150000.parquet', 'pageviews-20160102-160000.parquet', 'pageviews-20160102-170000.parquet', 'pageviews-20160102-180000.parquet', 'pageviews-20160102-190000.parquet', 'pageviews-20160102-200000.parquet', 'pageviews-20160102-210000.parquet', 'pageviews-20160102-220000.parquet', 'pageviews-20160102-230000.parquet', 'pageviews-20160103-000000.parquet', 'pageviews-20160103-010000.parquet', 'pageviews-20160103-020000.parquet', 'pageviews-20160103-030000.parquet', 'pageviews-20160103-040000.parquet', 'pageviews-20160103-050000.parquet', 'pageviews-20160103-060000.parquet', 'pageviews-20160103-070000.parquet', 'pageviews-20160103-080000.parquet', 'pageviews-20160103-090000.parquet', 'pageviews-20160103-100000.parquet', 'pageviews-20160103-110000.parquet', 'pageviews-20160103-120000.parquet', 'pageviews-20160103-130000.parquet', 'pageviews-20160103-140000.parquet', 'pageviews-20160103-150000.parquet', 'pageviews-20160103-160000.parquet', 'pageviews-20160103-170000.parquet', 'pageviews-20160103-180000.parquet', 'pageviews-20160103-190000.parquet', 'pageviews-20160103-200000.parquet', 'pageviews-20160103-210000.parquet', 'pageviews-20160103-220000.parquet', 'pageviews-20160103-230000.parquet', 'pageviews-20160104-000000.parquet', 'pageviews-20160104-010000.parquet', 'pageviews-20160104-020000.parquet', 'pageviews-20160104-030000.parquet', 'pageviews-20160104-040000.parquet', 'pageviews-20160104-050000.parquet', 'pageviews-20160104-060000.parquet', 'pageviews-20160104-070000.parquet', 'pageviews-20160104-080000.parquet', 'pageviews-20160104-090000.parquet', 'pageviews-20160104-100000.parquet', 'pageviews-20160104-110000.parquet', 'pageviews-20160104-120000.parquet', 'pageviews-20160104-130000.parquet', 'pageviews-20160104-140000.parquet', 'pageviews-20160104-150000.parquet', 'pageviews-20160104-160000.parquet', 'pageviews-20160104-170000.parquet', 'pageviews-20160104-180000.parquet', 'pageviews-20160104-190000.parquet', 'pageviews-20160104-200000.parquet', 'pageviews-20160104-210000.parquet', 'pageviews-20160104-220000.parquet', 'pageviews-20160104-230000.parquet', 'pageviews-20160105-000000.parquet', 'pageviews-20160105-010000.parquet', 'pageviews-20160105-020000.parquet', 'pageviews-20160105-030000.parquet', 'pageviews-20160105-040000.parquet', 'pageviews-20160105-050000.parquet', 'pageviews-20160105-060000.parquet', 'pageviews-20160105-070000.parquet', 'pageviews-20160105-080000.parquet', 'pageviews-20160105-090000.parquet', 'pageviews-20160105-100000.parquet', 'pageviews-20160105-110000.parquet', 'pa ...

# %%
not_down_files = list(set(parquet_need) - set(parquet_parttern))
print(type(not_down_files))
url_path = 'https://dumps.wikimedia.org/other/pageviews/2016/2016-01/'
not_download_urls = []
for file in not_down_files:
    not_down_url = (url_path + file.replace(".parquet", ".gz"))
    not_download_urls.append(not_down_url)
# Out:
# <class 'list'>

# %%
import concurrent.futures
import threading
import os
import subprocess
from datetime import datetime, timedelta
import gzip

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, lit, sum as _sum
from pyspark.sql.types import IntegerType, DateType, StringType



def log_file(message):
    catching_time =datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    with open(filelog, 'a') as log_writer:
        log_writer.write(catching_time + "---" + message +"\n")
    return filelog

def create_url(year=2016, month=1, date=1, time=1):
    year = f'{int(year):04}'
    month = f'{int(month):02}'
    date = f'{int(date):02}'
    time = f'{int(time):02}'
    url = f'https://dumps.wikimedia.org/other/pageviews/{year}/{year}-{month}/pageviews-{year}{month}{date}-{time}0000.gz'
    return url

def download_gzfiles(gzfolder_path,url,downloaded_files_lock, downloaded_files):
    # file_base_name = url.split("/")[-1]
    # file_name = os.path.join(gzfolder_path, file_base_name)
    gzfile_name = url.split("/")[-1]
    gzfile_path = os.path.join(gzfolder_path, gzfile_name)

    # Lock to ensure thread-safety when modifying downloaded_files set
    with downloaded_files_lock:
        # Check if the file already exists in the set
        if gzfile_path in downloaded_files:
            print(f"File {gzfile_path} already exists. Skipping download.")
            return  # Skip the download if the file is in the set
    
     # Check if the file already exists
    if os.path.exists(gzfile_path):
        print(f"File {gzfile_path} already exists. Skipping download.")
        return  # Skip the download if the file exists
    
    try:
        # Download the file
        print(f'{gzfile_name} is downloading ...')
        subprocess.run(["curl", "-o", gzfile_path, url], check=True)
        # Decompress the file
        # subprocess.run(["gunzip", file_name], check=True)
        with downloaded_files_lock:
            downloaded_files.add(gzfile_path)  # Mark the file as downloaded
        print(f"Download and decompression complete: {gzfile_path}")
    except subprocess.CalledProcessError as e:
        print(f"Error downloading {url}: {e}")
        log_file(f"Error downloading {url}: {e}")

def execute_download_gzfiles(res_url, batch_size=12):
    downloaded_files = set()  # Set to track downloaded files
    downloaded_files_lock = threading.Lock()  # Lock to make the downloaded_files set thread-safe
    
    # Run in parallel
    for idx in range(0, len(res_url), batch_size):
        batch = res_url[idx: idx+batch_size]
        with concurrent.futures.ThreadPoolExecutor(max_workers=3) as executor:
            executor.map(lambda url: download_gzfiles(gzfolder_path, url, downloaded_files_lock, downloaded_files), batch)

def is_valid_gz(gzfile_path):
    try:
        with gzip.open(gzfile_path, 'rb') as gz_check:
            gz_check.read(1)  # Try reading one byte
        return True
    except (gzip.BadGzipFile, OSError):
        return False
         

def checkvalid_gzfile(gzfolder_path):
    """Ensure the folder contains 24 valid .gz files, otherwise re-download."""
    # Get the list of all .gz files in the folder
    gzfile_path_list = [os.path.join(gzfolder_path, gzfile_name) 
                        for gzfile_name in os.listdir(gzfolder_path) if gzfile_name.endswith('.gz')]
    
    # Check if the folder contains exactly 24 files
    if len(gzfile_path_list) == len(not_download_urls):
        # Check for invalid .gz files
        invalid_files = [gzfile for gzfile in gzfile_path_list if not is_valid_gz(gzfile)]
        
        if invalid_files:
            # Remove invalid files
            for invalid_file in invalid_files:
                print(f"Removing invalid file: {invalid_file}")
                os.remove(invalid_file)
            
            # Re-download the batch
            print("Re-downloading missing or invalid files...")
            execute_download_gzfiles(gzfolder_path)  # Adjust this function to handle the folder re-download
    else:
        print(f"Expected 24 files, found {len(gzfile_path_list)}. Re-downloading...")
        execute_download_gzfiles(gzfolder_path)

def process_single_file(spark,gzfile_name, gzfolder_path, parquet_folder_path, pagenames):
    try:
        gzfile_path = os.path.join(gzfolder_path, gzfile_name)
        # gzfile_name = os.path.basename(gzfile_path)
        # Validate gzfile_name format
        if len(gzfile_name.strip().replace(".gz", "").split('-')) != 3:
            raise ValueError(f"Unexpected gzfile_name format: {gzfile_name}")
        _, date_str, time_str = gzfile_name.strip().replace(".gz", "").split('-')

        # Calculate date and time
        date_collection = (datetime.strptime(date_str, "%Y%m%d") - timedelta(days=1)).strftime("%Y-%m-%d")\
                            if time_str == "000000"\
                            else datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
        time_collection = f'{time_str[:2]}:{time_str[2:4]}:{time_str[4:]}'

        output_parquetfile_path= os.path.join(parquet_folder_path, gzfile_name.replace(".gz", ".parquet"))

        # Skip processing if the Parquet file already exists
        if os.path.exists(output_parquetfile_path):
            print(f"Skipping {gzfile_name}: Parquet file already exists.")
            return

        print(f"Processing {gzfile_name}")

        # Read the .gz file into a DataFrame on the driver node
        df = spark.read.text(gzfile_path)

        # Transform the DataFrame
        df_split = df.withColumn("split_value", split(df["value"], " "))
        df_transformed = df_split.select(
            df_split["split_value"].getItem(0).alias("domain"),
            df_split["split_value"].getItem(1).alias("pagename"),
            df_split["split_value"].getItem(2).cast(IntegerType()).alias("pageview"),
            df_split["split_value"].getItem(3).cast(IntegerType()).alias("other")
        ).drop("other").filter(col("pagename").isin(pagenames))

        df_final = df_transformed.groupBy("domain", "pagename") \
            .agg(_sum(col("pageview")).cast(IntegerType()).alias("sumpageviewcount")) \
            .withColumn("date_collection", lit(date_collection).cast(StringType()))\
            .withColumn("time_collection", lit(time_collection).cast(StringType())) \
            .orderBy("domain", "pagename")
        # Ensure the output directory exists
        os.makedirs(parquet_folder_path, exist_ok=True)
        # Write to Parquet on the driver node
        df_final.write.parquet(output_parquetfile_path)

    except Exception as e:
        error_message = f"Error processing {gzfile_path}: {e}"
        print(error_message)
        log_file(error_message)
      

def remove_gzfiles(gzfolder_path):
    for gzfile in os.listdir(gzfolder_path):
        gzfile_path = os.path.join(gzfolder_path, gzfile)
        os.remove(gzfile_path)

# %%
# Main logic
if __name__ == "__main__":
    spark = SparkSession.builder \
    .appName("gz_file_to_parquet") \
    .config("spark.executor.memory", "4g") \
    .config("spark.executor.cores", "4") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

    gzfolder_path = "/Users/GianNT/Documents/Mr_G/Py_DE_Project/project_1_create_DW/download_test/gzfolder"
    # gzfolder_path = "/Volumes/ESD-ISO/gzfolder"
    parquet_folder_path= "/Users/GianNT/Documents/Mr_G/Py_DE_Project/project_1_create_DW/download_test/parquet"
    pagenames = ["Google","Facebook","Amazon","Microsoft", "Apple", 'Walmart']
    filelog = r"/Users/GianNT/Documents/Mr_G/Py_DE_Project/project_1_create_DW/download_test/combine_test.txt"

   
    # run tasks
    execute_download_gzfiles(not_download_urls)
    checkvalid_gzfile(gzfolder_path)
    
    for gzfile_name in os.listdir(gzfolder_path):
        if gzfile_name.endswith('.gz'):
            process_single_file(spark,gzfile_name, gzfolder_path, parquet_folder_path, pagenames)
    
    remove_gzfiles(gzfolder_path)
    spark.stop()
